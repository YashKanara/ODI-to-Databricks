-- %% [markdown]
-- # `TRG_DEP_INSERT.sql` Conversion**Conversion Timestamp:** 2024-07-30 12:00:00**Description:** This notebook converts the ODI SQL for inserting data into the `TRG_DEP` table from the `DEPARTMENTS` table.

-- %%
%sql
-- SCEN_TASK_NO in {10}: Initial Setup (placeholder)-- SCEN_TASK_NO in {20}: Data Preparation (placeholder)-- SCEN_TASK_NO in {30}: Insert into Target TableINSERT  INTO workspace.hr.trg_dep  (    department_id ,    department_name ,    manager_id ,    location_id  )SELECT  departments.department_id ,  departments.department_name ,  departments.manager_id ,  departments.location_idFROM  workspace.hr.departments departments;

-- %% [markdown]
-- ## Conversion Notes- Oracle hints `/*+ APPEND PARALLEL */` have been removed as they are not applicable to Databricks Delta Lake.- Oracle schema `HR` has been converted to `workspace.hr` in lowercase, following Databricks naming conventions.- Table names `TRG_DEP` and `DEPARTMENTS` have been converted to lowercase `trg_dep` and `departments` respectively.- No `dbutils.widgets` calls were necessary as no ODI global or schema parameters were identified in the source SQL.
