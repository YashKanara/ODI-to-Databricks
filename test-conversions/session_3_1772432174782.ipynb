# %% [markdown]
# # ODI SQL Conversion: simple_insert.txt
#
# **Conversion Timestamp:** 2024-07-30 12:00:00
#
# **Description:** This notebook converts an ODI SQL file containing a direct INSERT statement from a source table into a target table.

# %% [markdown]
# # Data Loading

# %%
# %sql
-- SCEN_TASK_NO in {10}, {20}, {30}: These tasks are markers in the original ODI session.
-- The primary DML operation is the INSERT statement below.
INSERT 
  INTO workspace.hr.trg_loc
  (
    LOCATION_ID ,
    STREET_ADDRESS ,
    POSTAL_CODE ,
    CITY ,
    STATE_PROVINCE ,
    COUNTRY_ID 
  ) 
SELECT 
  LOCATIONS.LOCATION_ID ,
  LOCATIONS.STREET_ADDRESS ,
  LOCATIONS.POSTAL_CODE ,
  LOCATIONS.CITY ,
  LOCATIONS.STATE_PROVINCE ,
  LOCATIONS.COUNTRY_ID  
FROM 
  workspace.hr.locations AS LOCATIONS;

# %% [markdown]
# # Validation

# %%
# %sql
SELECT COUNT(*) AS total_records_inserted
FROM workspace.hr.trg_loc;

# %% [markdown]
# # Conversion Notes and Manual Actions Required
#
# 1.  **Schema and Table Naming:** Original Oracle schema `HR` was converted to `workspace.hr`. Table names `TRG_LOC` and `LOCATIONS` were converted to `trg_loc` and `locations` respectively, following Databricks naming conventions (lowercase, prefixed with `workspace.`).
# 2.  **Oracle Hints:** The `/*+ APPEND PARALLEL */` hint was removed as it is specific to Oracle and not applicable in Databricks Delta Lake.
# 3.  **Table Existence:** This notebook assumes that `workspace.hr.trg_loc` and `workspace.hr.locations` tables already exist in your Databricks environment with compatible schemas.
# 4.  **Error Handling/Logging:** The original ODI session might have included error handling or logging mechanisms. These are not directly converted here. Consider implementing Databricks-native logging or error table patterns if needed for a production workload.
