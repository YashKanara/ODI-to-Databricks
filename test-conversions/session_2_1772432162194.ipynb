# %% [markdown]
# # ODI to Databricks Migration
#
# **Source File:** `TARGET.sql`
# **Conversion Date:** 2024-07-30
#
# **Description:** This notebook performs a full load insert into the `TRG_DEP` table from `DEPARTMENTS` table.

# %%
# This cell is reserved for Databricks widgets (ETL parameters).
# No specific ODI parameters (#GLOBAL, #SCHEMA) were identified in the source SQL, 
# but this cell is included for structural consistency.
# Example: dbutils.widgets.text("ETL_JOB_TYPE", "FULL")

# %% [markdown]
# ## ETL Parameters

# %%
display(spark.sql("SELECT 'No parameters identified' AS Info"))
# Example: display(spark.sql("SELECT '${ETL_JOB_TYPE}' AS ETL_JOB_TYPE"))

# %% [markdown]
# ## Load Target Department Table

# %%
# %sql
-- SCEN_TASK_NO in {10}: Initial tasks (placeholder)
-- SCEN_TASK_NO in {20}: (placeholder)
-- SCEN_TASK_NO in {30}: Insert into Target Department table

INSERT INTO workspace.hr.trg_dep
  (
    department_id ,
    department_name ,
    manager_id ,
    location_id
  )
SELECT
  departments.department_id ,
  departments.department_name ,
  departments.manager_id ,
  departments.location_id
FROM
  workspace.hr.departments AS departments;

# %% [markdown]
# ## Validation

# %%
# %sql
SELECT COUNT(*) AS total_records_in_trg_dep
FROM workspace.hr.trg_dep;

# %% [markdown]
# ## Conversion Notes
#
# - Oracle hints `/*+ APPEND PARALLEL */` were removed as they are not applicable to Databricks Delta Lake.
# - Oracle schema `HR` and table names `TRG_DEP`, `DEPARTMENTS` were converted to lowercase and prefixed with `workspace.` (`workspace.hr.trg_dep`, `workspace.hr.departments`).
# - The `SCEN_TASK_NO` entries were preserved as comments in the SQL cell for context.
# - No `CREATE TABLE` statements were provided in the source SQL, thus none were generated. It is assumed the `workspace.hr.trg_dep` table already exists with appropriate schema.
