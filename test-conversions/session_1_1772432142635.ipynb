# %% [markdown]
# # `HR_TRG_EMP_LOAD.txt` Conversion**Conversion Timestamp:** 2024-07-30 12:00:00 UTC**Description:** This notebook loads data from the `employees` table into the `trg_emp` target table within the `hr` schema.

# %%
# SCEN_TASK_NO in {10}# SCEN_TASK_NO in {20}dbutils.widgets.text("ETL_JOB_TYPE", "")dbutils.widgets.text("DATASOURCE_NUM_ID", "")dbutils.widgets.text("ETL_PROC_WID", "")dbutils.widgets.text("ODI_SESS_NO", "")

# %% [markdown]
# ## ETL Parameters

# %%
display(spark.sql("""
  SELECT
    '${ETL_JOB_TYPE}' AS ETL_JOB_TYPE,
    '${DATASOURCE_NUM_ID}' AS DATASOURCE_NUM_ID,
    '${ETL_PROC_WID}' AS ETL_PROC_WID,
    '${ODI_SESS_NO}' AS ODI_SESS_NO
"""))

# %% [markdown]
# ## Insert into Target

# %%
# %sql
-- SCEN_TASK_NO in {30}INSERT  INTO workspace.hr.trg_emp  (    employee_id ,    first_name ,    last_name ,    email ,    phone_number ,    hire_date ,    job_id ,    salary ,    commission_pct ,    manager_id ,    department_id  )SELECT  e.employee_id ,  e.first_name ,  e.last_name ,  e.email ,  e.phone_number ,  e.hire_date ,  e.job_id ,  e.salary ,  e.commission_pct ,  e.manager_id ,  e.department_idFROM  workspace.hr.employees AS e;

# %% [markdown]
# ## Optimize Target

# %%
# %sql
-- Disable ZORDER stats check to prevent DELTA_ZORDERING_ON_COLUMN_WITHOUT_STATSSET spark.databricks.delta.optimize.zorder.checkStatsCollection.enabled = false;OPTIMIZE workspace.hr.trg_emp ZORDER BY (employee_id);

# %% [markdown]
# ## Cleanup

# %% [markdown]
# ## Validation

# %%
# %sql
SELECT COUNT(*) FROM workspace.hr.trg_emp;

# %%
# %sql
SELECT * FROM workspace.hr.trg_emp ORDER BY employee_id LIMIT 10;

# %% [markdown]
# ## Conversion Notes- Oracle hints `/*+ APPEND PARALLEL */` have been removed as they are not applicable to Databricks Spark SQL.- Oracle schema `HR` has been converted to `workspace.hr`.- Table names `TRG_EMP` and `EMPLOYEES` have been converted to lowercase `trg_emp` and `employees` respectively.- An `OPTIMIZE ... ZORDER BY (employee_id)` statement has been added for performance, preceded by the necessary `SET` command to disable stats collection check.- Standard Databricks widgets for ETL parameters have been included, although not directly used in this specific SQL statement.
