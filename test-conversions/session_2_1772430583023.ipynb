# %% [markdown]
# # `TRG_DEP.txt` to Databricks Spark SQL Conversion
#
# **Conversion Timestamp:** 2024-07-30 12:00:00
#
# This notebook contains the converted Spark SQL logic for `TRG_DEP.txt`.
# It includes DDL for the target table and the main insert operation.
# No ODI parameters were detected in the source file.

# %%
# No ODI parameters (#GLOBAL or #SCHEMA) were found in the source file.
# Therefore, no dbutils widgets are created for this notebook.

# %% [markdown]
# ## ETL Parameters

# %% [markdown]
# ## Target Table DDL
# *(Corresponds to SCEN_TASK_NO in {10} - Initial setup)*

# %%
# %sql
CREATE TABLE IF NOT EXISTS workspace.hr.trg_dep (
    DEPARTMENT_ID BIGINT,
    DEPARTMENT_NAME STRING,
    MANAGER_ID BIGINT,
    LOCATION_ID BIGINT
) USING DELTA;

# %% [markdown]
# ## Main Load Operation
# *(Corresponds to SCEN_TASK_NO in {20}, {30} and the subsequent INSERT statement)*

# %%
# %sql
INSERT INTO workspace.hr.trg_dep (
    DEPARTMENT_ID,
    DEPARTMENT_NAME,
    MANAGER_ID,
    LOCATION_ID
)
SELECT
    departments.DEPARTMENT_ID,
    departments.DEPARTMENT_NAME,
    departments.MANAGER_ID,
    departments.LOCATION_ID
FROM
    workspace.hr.departments AS departments;

# %% [markdown]
# ## Validation

# %%
# %sql
SELECT COUNT(*) AS total_records_in_trg_dep FROM workspace.hr.trg_dep;

# %% [markdown]
# ## Cleanup
# No temporary staging or flow tables were created in this process, so no explicit cleanup is required here.

# %% [markdown]
# ## Conversion Notes and Manual Actions Required
#
# 1.  **Schema Inference:** The DDL for `workspace.hr.trg_dep` was inferred from the `INSERT` statement's column list.
# 2.  **Oracle Hint Removed:** The `/*+ APPEND PARALLEL */` hint has been removed as it is not applicable in Databricks Spark SQL.
# 3.  **Table Existence:** It is assumed that the source table `workspace.hr.departments` already exists and has a compatible schema. If not, its DDL would need to be created manually.
# 4.  **`SCEN_TASK_NO`:** The empty `SCEN_TASK_NO` lines `{10}, {20}, {30}` from the original file have been used as markers for logical sections within the notebook.
